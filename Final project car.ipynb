# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style("darkgrid")
import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv("car data.csv")

# %%
data
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Selling_type Transmission  Owner
# 0         Dealer       Manual      0
# 1         Dealer       Manual      0
# ...

# %%
data.describe()
# Out:
#               Year  Selling_Price  Present_Price     Driven_kms       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.642584   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
data.drop("Car_Name",axis = 1,inplace = True)

# %%
data
# Out:
#      Year  Selling_Price  Present_Price  Driven_kms Fuel_Type Selling_type  \
# 0    2014           3.35           5.59       27000    Petrol       Dealer
# 1    2013           4.75           9.54       43000    Diesel       Dealer
# 2    2017           7.25           9.85        6900    Petrol       Dealer
# 3    2011           2.85           4.15        5200    Petrol       Dealer
# 4    2014           4.60           6.87       42450    Diesel       Dealer
# ..    ...            ...            ...         ...       ...          ...
# 296  2016           9.50          11.60       33988    Diesel       Dealer
# 297  2015           4.00           5.90       60000    Petrol       Dealer
# 298  2009           3.35          11.00       87934    Petrol       Dealer
# 299  2017          11.50          12.50        9000    Diesel       Dealer
# 300  2016           5.30           5.90        5464    Petrol       Dealer
#
#     Transmission  Owner
# 0         Manual      0
# ...

# %%
data.isnull().sum()
# Out:
# Year             0
# Selling_Price    0
# Present_Price    0
# Driven_kms       0
# Fuel_Type        0
# Selling_type     0
# Transmission     0
# Owner            0
# dtype: int64

# %%
data.describe()
# Out:
#               Year  Selling_Price  Present_Price     Driven_kms       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.642584   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
data['Current Year']=2025

# %%
data['Current Year']- data['Year']
# Out:
# 0      11
# 1      12
# 2       8
# 3      14
# 4      11
#        ..
# 296     9
# 297    10
# 298    16
# 299     8
# 300     9
# Length: 301, dtype: int64

# %%
data['no_year']=data['Current Year']- data['Year']

# %%
data
# Out:
#      Year  Selling_Price  Present_Price  Driven_kms Fuel_Type Selling_type  \
# 0    2014           3.35           5.59       27000    Petrol       Dealer
# 1    2013           4.75           9.54       43000    Diesel       Dealer
# 2    2017           7.25           9.85        6900    Petrol       Dealer
# 3    2011           2.85           4.15        5200    Petrol       Dealer
# 4    2014           4.60           6.87       42450    Diesel       Dealer
# ..    ...            ...            ...         ...       ...          ...
# 296  2016           9.50          11.60       33988    Diesel       Dealer
# 297  2015           4.00           5.90       60000    Petrol       Dealer
# 298  2009           3.35          11.00       87934    Petrol       Dealer
# 299  2017          11.50          12.50        9000    Diesel       Dealer
# 300  2016           5.30           5.90        5464    Petrol       Dealer
#
#     Transmission  Owner  Current Year  no_year
# ...

# %%
data.head()
# Out:
#    Year  Selling_Price  Present_Price  Driven_kms Fuel_Type Selling_type  \
# 0  2014           3.35           5.59       27000    Petrol       Dealer
# 1  2013           4.75           9.54       43000    Diesel       Dealer
# 2  2017           7.25           9.85        6900    Petrol       Dealer
# 3  2011           2.85           4.15        5200    Petrol       Dealer
# 4  2014           4.60           6.87       42450    Diesel       Dealer
#
#   Transmission  Owner  Current Year  no_year
# 0       Manual      0          2025       11
# 1       Manual      0          2025       12
# 2       Manual      0          2025        8
# 3       Manual      0          2025       14
# 4       Manual      0          2025       11

# %%
data.drop(['Year',"Current Year"],axis=1,inplace=True)

# %%
data
# Out:
#      Selling_Price  Present_Price  Driven_kms Fuel_Type Selling_type  \
# 0             3.35           5.59       27000    Petrol       Dealer
# 1             4.75           9.54       43000    Diesel       Dealer
# 2             7.25           9.85        6900    Petrol       Dealer
# 3             2.85           4.15        5200    Petrol       Dealer
# 4             4.60           6.87       42450    Diesel       Dealer
# ..             ...            ...         ...       ...          ...
# 296           9.50          11.60       33988    Diesel       Dealer
# 297           4.00           5.90       60000    Petrol       Dealer
# 298           3.35          11.00       87934    Petrol       Dealer
# 299          11.50          12.50        9000    Diesel       Dealer
# 300           5.30           5.90        5464    Petrol       Dealer
#
#     Transmission  Owner  no_year
# 0         Manual      0       11
# 1         Manual      0       12
# 2         Manual      0        8
# ...

# %%
pd.get_dummies(data.Selling_type,dtype="int",drop_first=True)
# Out:
#      Individual
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0
# ..          ...
# 296           0
# 297           0
# 298           0
# 299           0
# 300           0
#
# [301 rows x 1 columns]

# %%
final_dataset=pd.get_dummies(data,drop_first=True,dtype="int")

# %%
final_dataset
# Out:
#      Selling_Price  Present_Price  Driven_kms  Owner  no_year  \
# 0             3.35           5.59       27000      0       11
# 1             4.75           9.54       43000      0       12
# 2             7.25           9.85        6900      0        8
# 3             2.85           4.15        5200      0       14
# 4             4.60           6.87       42450      0       11
# ..             ...            ...         ...    ...      ...
# 296           9.50          11.60       33988      0        9
# 297           4.00           5.90       60000      0       10
# 298           3.35          11.00       87934      0       16
# 299          11.50          12.50        9000      0        8
# 300           5.30           5.90        5464      0        9
#
#      Fuel_Type_Diesel  Fuel_Type_Petrol  Selling_type_Individual  \
# 0                   0                 1                        0
# 1                   1                 0                        0
# ...

# %%
final_dataset.head()
# Out:
#    Selling_Price  Present_Price  Driven_kms  Owner  no_year  Fuel_Type_Diesel  \
# 0           3.35           5.59       27000      0       11                 0
# 1           4.75           9.54       43000      0       12                 1
# 2           7.25           9.85        6900      0        8                 0
# 3           2.85           4.15        5200      0       14                 0
# 4           4.60           6.87       42450      0       11                 1
#
#    Fuel_Type_Petrol  Selling_type_Individual  Transmission_Manual
# 0                 1                        0                    1
# 1                 0                        0                    1
# 2                 1                        0                    1
# 3                 1                        0                    1
# 4                 0                        0                    1

# %%
final_dataset.corr()
# Out:
#                          Selling_Price  Present_Price  Driven_kms     Owner  \
# Selling_Price                 1.000000       0.878914    0.029187 -0.088344
# Present_Price                 0.878914       1.000000    0.203618  0.008058
# Driven_kms                    0.029187       0.203618    1.000000  0.089216
# Owner                        -0.088344       0.008058    0.089216  1.000000
# no_year                      -0.236141       0.047192    0.524342  0.182104
# Fuel_Type_Diesel              0.552339       0.473390    0.172515 -0.053469
# Fuel_Type_Petrol             -0.540571      -0.465326   -0.172874  0.055687
# Selling_type_Individual      -0.550724      -0.512121   -0.101419  0.124269
# Transmission_Manual          -0.367128      -0.348776   -0.162510 -0.050316
#
#                           no_year  Fuel_Type_Diesel  Fuel_Type_Petrol  \
# Selling_Price           -0.236141          0.552339         -0.540571
# ...

# %%
plt.figure(figsize=(8,8))
sns.heatmap(final_dataset.corr(),annot=True)
# Out:
# <Axes: >

# %%
X=final_dataset.iloc[:,1:]
y=final_dataset.Selling_Price

# %%
X['Owner'].unique()
# Out:
# array([0, 1, 3], dtype=int64)

# %%
X
# Out:
#      Present_Price  Driven_kms  Owner  no_year  Fuel_Type_Diesel  \
# 0             5.59       27000      0       11                 0
# 1             9.54       43000      0       12                 1
# 2             9.85        6900      0        8                 0
# 3             4.15        5200      0       14                 0
# 4             6.87       42450      0       11                 1
# ..             ...         ...    ...      ...               ...
# 296          11.60       33988      0        9                 1
# 297           5.90       60000      0       10                 0
# 298          11.00       87934      0       16                 0
# 299          12.50        9000      0        8                 1
# 300           5.90        5464      0        9                 0
#
#      Fuel_Type_Petrol  Selling_type_Individual  Transmission_Manual
# 0                   1                        0                    1
# ...

# %%
y
# Out:
# 0       3.35
# 1       4.75
# 2       7.25
# 3       2.85
# 4       4.60
#        ...
# 296     9.50
# 297     4.00
# 298     3.35
# 299    11.50
# 300     5.30
# Name: Selling_Price, Length: 301, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
regressor=RandomForestRegressor()

# %%
regressor.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred = regressor.predict(X_test)

# %%
from sklearn.metrics import r2_score,mean_squared_error

# %%
r2_score(y_test,y_pred)
# Out:
# 0.959943320068023

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 1.012525459508197

# %%
import pickle

file = open('random_forest_regression_model.pkl', 'wb')


pickle.dump(regressor, file)

# %%
file = open('random_forest_regression_model.pkl', 'rb')


model = pickle.load(file)

# %%
model
# Out:
# RandomForestRegressor()

# %%
pre = model.predict([[  0.826,6000.000,0.000,13.000,0.000,1.000,1.000,1.000]])

# %%
X_test.iloc[1,:]
# Out:
# Present_Price                 0.826
# Driven_kms                 6000.000
# Owner                         0.000
# no_year                      14.000
# Fuel_Type_Diesel              0.000
# Fuel_Type_Petrol              1.000
# Selling_type_Individual       1.000
# Transmission_Manual           1.000
# Name: 150, dtype: float64

# %%
y_test.iloc[1]
# Out:
# 0.5

# %%
0.5-0.4687
# Out:
# 0.031299999999999994

# %%
pre
# Out:
# array([0.4891])

# %%
output = round(pre[0],2)

# %%
round(pre[0],2)
# Out:
# 0.49

# %%
"You Can Sell The Car at {}".format(output)
# Out:
# 'You Can Sell The Car at 0.49'
